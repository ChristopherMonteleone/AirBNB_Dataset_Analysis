# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('listings.csv')

# %%
print(data)
# Out:
#                        id                                               name  \
# 0                   44701        Jan1-8, 2023, New Years Plus CES conference
# 1                  113019                      MGM Signature Studio W/ View!
# 2                 1230857  2 Private Bedrooms in SW Las Vegas (Shared House)
# 3                  114140                MGM Signature 1BR/2BA Suite W/ View
# 4                  133084   Beautiful, Sleek, Sexy Condo -  Long Term Rental
# ...                   ...                                                ...
# 14803  704219412350302769           Snowbird Retreat - Casino & River views!
# 14804            53835732  Beautiful 2-bedroom condo w/ pool and river ac...
# 14805            46731800        Fall Special Cottage on the beach 1 Bedroom
# 14806            48994809                                 House On The River
# 14807  686234846647292111    Delightful 1 bd cottage a few steps to River #9
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14808 entries, 0 to 14807
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14808 non-null  int64
#  1   name                            14808 non-null  object
#  2   host_id                         14808 non-null  int64
#  3   host_name                       14369 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   14808 non-null  object
#  6   latitude                        14808 non-null  float64
#  7   longitude                       14808 non-null  float64
#  8   room_type                       14808 non-null  object
#  9   price                           14808 non-null  int64
#  10  minimum_nights                  14808 non-null  int64
#  11  number_of_reviews               14808 non-null  int64
# ...

# %%
data.describe()
# Out:
#                  id       host_id  neighbourhood_group      latitude  \
# count  1.480800e+04  1.480800e+04                  0.0  14808.000000
# mean   2.028741e+17  1.921017e+08                  NaN     36.088364
# std    2.975468e+17  1.555515e+08                  NaN      0.180612
# min    4.470100e+04  5.146000e+03                  NaN     35.024980
# 25%    3.651363e+07  4.040854e+07                  NaN     36.093355
# 50%    5.109042e+07  1.632140e+08                  NaN     36.108060
# 75%    5.872964e+17  3.314695e+08                  NaN     36.134020
# max    7.165309e+17  4.793378e+08                  NaN     36.842386
#
#           longitude         price  minimum_nights  number_of_reviews  \
# count  14808.000000  14808.000000    14808.000000       14808.000000
# mean    -115.152063    390.665249        7.829079          28.663155
# std        0.140201   1462.838461       21.248208          61.330665
# ...

# %%
data.neighbourhood
# Out:
# 0        Unincorporated Areas
# 1        Unincorporated Areas
# 2        Unincorporated Areas
# 3        Unincorporated Areas
# 4           City of Las Vegas
#                  ...
# 14803    Unincorporated Areas
# 14804    Unincorporated Areas
# 14805    Unincorporated Areas
# 14806    Unincorporated Areas
# 14807    Unincorporated Areas
# Name: neighbourhood, Length: 14808, dtype: object

# %%
pd.crosstab(data.neighbourhood, data.room_type)
# Out:
# room_type                Entire home/apt  Hotel room  Private room  \
# neighbourhood
# Boulder City                          14           0             4
# City of Henderson                    637           0           101
# City of Las Vegas                   1411           8           596
# City of Mesquite                      76           0             4
# City of North Las Vegas              391           0           168
# Nellis AFB                             4           0             0
# Unincorporated Areas                8302         327          2680
#
# room_type                Shared room
# neighbourhood
# Boulder City                       0
# City of Henderson                  0
# City of Las Vegas                 21
# City of Mesquite                   0
# City of North Las Vegas            4
# Nellis AFB                         0
# Unincorporated Areas              60

# %%
sns.catplot(x="room_type", y = "price", data=data, palette='plasma')
# Out:
# C:\Users\Chris\AppData\Local\Temp\ipykernel_6684\1408736517.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.catplot(x="room_type", y = "price", data=data, palette='plasma')

# %%
sns.catplot(x="neighbourhood", y = "price", kind="boxen", data=data, palette='plasma')

# %%
viz_4=data.plot(kind='scatter', x='longitude', y='latitude', label='availability_365', c='price',
                  cmap=plt.get_cmap('jet'),colorbar=True, alpha=0.4, figsize=(10,8))
viz_4.legend()

# %%
corr = data.corr(method='kendall')
plt.figure(figsize=(15,8))
plt.show()
sns.heatmap(corr, annot=True)
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=data.longitude,y=data.latitude,data=data,hue=data.neighbourhood)
plt.ioff()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=data.longitude,y=data.latitude,data=data,hue=data.room_type)
plt.ioff()
plt.show()
